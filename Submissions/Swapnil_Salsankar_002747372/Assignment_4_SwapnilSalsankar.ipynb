# %% [markdown]
# **1)** Given a set of positive integers and a target sum, is there a subset of the numbers that adds up to the target sum?Given a set of positive integers S and a target sum T, the Subset Sum problem asks whether there exists a subset S' of S such that the sum of elements in S' is equal to T.
#
# Given the set of positive integers = (4,5, 2, 8, 3} S=(4,5,2,8,3} and the target sum = 10 T=10, the
# Subset Sum problem is to determine whether there exists a subset S' of S such that the sum of elements in S'is equal to T
#
# A. Is the Set Partition problem in NP? Why or why not?
#
# B. Is the Set Partition problem NP-complete? If NP-complete, prove it?
#
# **Solution**
#
# **A. Is the Set Partition problem in NP? Why or why not?**
#
# Yes, the Set Partition problem is in NP (nondeterministic polynomial time). Given a proposed solution (two subsets that form a partition), you can easily verify in polynomial time whether the sum of numbers in each subset is equal and whether every element in the original multiset is included in one of the subsets. The verification process can be done in polynomial time, making the problem belong to the class NP.
#
# B. **Is the Set Partition problem NP-complete? If NP-complete, prove it:**
#
# To prove that the Set Partition problem is NP-complete, we need to show that it is both in NP and NP-hard. Since we've established it is in NP, the remaining part is to prove NP-hardness.
#
# B.1 Polynomial-Time Certifier for Set Partition:
#
# A polynomial-time certifier for the Set Partition problem checks whether a given solution is valid in polynomial time. The certifier verifies two conditions:
#
# Suppose we have the following multiset:
#
# S = {4, 5, 2, 8, 3}
#
# And we propose a partition:
#
# S1 = {4, 2,3}
#
# S2 = {5,8}
#
# Now, let's use a polynomial-time certifier to verify whether the proposed partition is valid:
#
# 1. Sum the Elements of Each Subset:
#
# • Sum of S'1: 4 + 2 + 3 = 9
#
# • Sum of S'2: 5 + 8 = 13
#
# 2. Check if Sums are Equal:
#
# • The sum of S'1 is not equal to the sum of S'2 (i.e. 9 ‡ 13).
#
# Since the sums are not equal, the proposed partition (S'1, S'2) is not a valid solution to the Set Partition problem.
#
# Now, let's take another example with a valid partition:
#
# S'1 = {4,5,2}
#
# S'2 = {8,3}
#
# 1. Sum the Elements of Each Subset:
#
# • Sum of S'1: 4 + 5 + 2 = 11
#
# • Sum of S'2: 8 + 3 = 11
#
# 2. Check if Sums are Equal:
#
# • The sum of S'1 is equal to the sum of S'2, (i.e., 11 = 11).
#
# In this case, the proposed partition (S'1, S'2) is a valid solution to the Set Partition problem.
#
# This example demonstrates the use of a polynomial-time certifier to check the validity of a proposed partition for the Set Partition problem. The certifier runs in polynomial time because it involves summing the elements of the subsets, and the size of the subsets is linear in the size of the original multiset.
#
# B.2 Reduction from Subset Sum to Set Partition:
#
# We'll show a reduction from the Subset Sum problem to the Set Partition problem. Given an instance of Subset Sum with a set of positive integers S and a target sum T, we construct an instance of Set Partition as follows:
#
# Given a set of positive integers A = {a1, a2, ...,an}  and a target sum T, does there exist a subset S' of A such that the sum of elements in S' is equal to T?
#
# Set Partition Construction:
#
# 1. For each element ai in A, add 2 • ai copies of ai to the multiset S.
# 2. Add T to S as a single element.
#
# Example:
# Let's work through an example:
#
# Subset Sum Instance:
#
# A = {4, 5, 2, 8, 3}
# T = 10
#
# Subset Sum Solution:
#
# One solution is S' = {2, 8} because 2 + 8 = 10.
#
# Set Partition Construction:
# 1. For each element ai, in A, add 2 • ai copies of ai to S:
#
# S = {4,4, 5, 5, 2, 2, 8, 8, 3, 3}
#
# 2. Add T' to S as a single element:
#
# S = {4, 4, 5, 5, 2, 2, 8, 8, 3, 3, 10}
#
# Analysis:
#
# • If there is a subset S' of A that adds up to T, then the corresponding partition of S into two subsets with equal sums is S1 = {2, 8, 10} and S2 = {4, 4, 5, 5, 2, 3, 3, 8}.
#
# • If there is a partition of S into two subsets with equal sums, such as S1 = {2, 8, 10} and S2 = (4, 4, 5, 5, 2, 3, 3, 8}, then the subset corresponding to the gements of A (excluding the single
# element T = 10) forms a subset of A that adds up to T (S' = {2,8}).
#
# Conclusion:
#
# This example illustrates the reduction from the Subset Sum problem to the Set Partition problem.
# The construction of the Set Partition instance from a Subset Sum instance is done in polynomial time, and the solution to the Set Partition instance corresponds to the solution of the Subset Sum instance. Therefore, the Set Partition problem is NP-complete.

# %% [markdown]
# **2)** A transportation company manages a fleet of buses operating on various routes. Each route is designated for specific time slots, and there are constraints restricting the overlap of certain routes. For example, if two routes share common stops or resources, they cannot operate simultaneously. The company is in need of an algorithm to determine whether a given set of bus routes can be scheduled without conflicts. This problem is analogous to the original contracting company scenario, involving the scheduling of tasks (bus routes) while adhering to predefined constraints.
#
# A. polynomial-time certifier.
#
# B.  Reduction Subset-Sum was the most natural reduction.
#
# But you cannot just state this, you must show this.
#
# **Solution**
#
# **A.** Polynomial-Time Certifier for Bus Scheduling Problem:
#
# A polynomial-time certifier for the Bus Scheduling Problem checks whether a proposed solution is valid in polynomial time. The certifier verifies two conditions:
#
# Non-overlapping Constraints: Check that no two bus routes in the given set overlap in terms of time slots or shared stops/resources.
#
# Scheduling Completeness: Ensure that each bus route in the set has been scheduled within its designated time slot.
#
# The certifier runs in polynomial time because each condition can be checked in linear or constant time, making the overall verification process polynomial.
#
# **B. **Reduction from Subset Sum to Bus Scheduling Problem:
#
# To prove that the Bus Scheduling Problem is NP-complete, we'll show a reduction from the Subset Sum problem. Given an instance of Subset Sum with a set of positive integers S and a target sum T, construct an instance of the Bus Scheduling Problem as follows:
#
# 1.Bus Routes and Time Slots:
#
# Create a bus route for each number in the Subset Sum instance.
#
# Assign a time slot for each bus route corresponding to the number in S.
#
# 2.Constraints:
#
# For each pair of bus routes i and j where i≠j, impose a constraint that they cannot overlap if the corresponding numbers in S do not sum up to the target sum T.
#
# Claim: There exists a subset of S with a sum equal to T if and only if there exists a valid schedule for the bus routes in the Bus Scheduling instance.
#
# Proof:
#
# If there exists a subset of S with a sum equal to T, then the corresponding bus routes can be scheduled in a way that avoids conflicts, as they represent a valid solution to Subset Sum.
#
# If there exists a valid schedule for the bus routes, then the non-overlapping constraints ensure that the corresponding numbers in S sum up to T.
#
# This reduction can be done in polynomial time, and it establishes the NP-hardness of the Bus Scheduling Problem. Since we've shown that it's in NP (using the polynomial-time certifier), the Bus Scheduling Problem is NP-complete.
#
#
# Example: Bus Scheduling Problem
#
# Let's consider a concrete example to illustrate the Bus Scheduling Problem and its reduction from Subset Sum:
#
# Subset Sum Instance:
#
# S = {3,1, 4, 2,2}, T=7
#
# Construction of Bus Scheduling Problem Instance:
#
# 1. Bus Routes and Time Slots:
#
# • Create bus routes corresponding to the numbers in S: R1, R2, Rs, Ra, Rs.
#
# • Assign time slots to each bus route: T1, T2, T3, T4, Ts.
#
# 2. Constraints:
#
# • For each pair of bus routes i and j where i ‡ j, impose a constraint that they cannot overlap if the corresponding numbers in S do not sum up to the target sum T.
#
# ![image.png](data:image/png;base64,...)
#
# Subset Sum Solution:
#
# {3, 4} because 3 + 4 = 7 = T
#
# Corresponding Bus Scheduling Solution:
#
# {R1, R3} because T1 n T3 = 0
#
# In this example, the solution to the Subset Sum problem ({3, 4}) corresponds to a valid schedule for the bus routes in the Bus Scheduling instance ({R1, Rs}), satisfying the constraints.

# %% [markdown]
# 3) In the context of Randomized Approximate Counting for 3-SAT, the objective is to develop a probabilistic algorithm for estimating the number of satisfying assignments in a given Boolean formula expressed in 3-SAT form.
# consider a 3-SAT formula with four clauses: (A OR B OR C), (¬A OR ¬B OR C), (A OR ¬B OR ¬C), and (¬A OR B OR ¬C). Randomly assigning truth values to the literals and observing that 60% of the generated assignments satisfy the clauses, the algorithm would estimate that approximately 60% of all possible assignments satisfy the entire formula, providing a useful approximation in scenarios where exact counting is infeasible.
#
# A. What is the expected number of satisfied clauses if each clause has just one literal and we
# randomly assign the truth value by flipping a fair coin?
#
# B. If each clause has just one literal can we always find a solution that will satisfy all k clauses?
#
# C. Consider a Max-SAT problem whose clauses can have any number of n literals. That is with k
# clauses, n literals and each clause can have from 1 up to n literals (1,2, ... n literals in a clause).
# Give a randomized polynomial-time algorithm that satisfies at least 55% of the k clauses
#
# **Solution**
#
# A. Expected Number of Satisfied Clauses with Single Literal
# In the context of a 3-SAT formula where each clause has just one literal, the expected number of satisfied clauses can be determined by considering the probability of satisfying a single-literal clause. If we randomly assign truth values to the literals by flipping a fair coin, the probability of satisfying a clause with one literal is 1/2. Given this, the expected number of satisfied clauses in the 3-SAT formula would be half the total number of clauses.
#
# B. Satisfying All Clauses with Single Literal
# When each clause has just one literal, it is not guaranteed that a solution can be found to satisfy all clauses. This is because the satisfaction of each clause depends on the outcome of flipping a fair coin, and there's a probability of 1/2 that a randomly assigned truth value satisfies a clause. Therefore, the probability of satisfying all clauses decreases exponentially with the number of clauses, and it's not assured that a solution satisfying all clauses can always be found.
#
# C. Randomized Polynomial-Time Algorithm for Max-SAT with Arbitrary Literal Count
# Consider a Max-SAT problem where clauses can have any number of literals, and the goal is to design a randomized polynomial-time algorithm that satisfies at least 55% of the k clauses. Initialize the algorithm by randomly assigning truth values to the literals. In each iteration, evaluate the number of satisfied clauses and choose a clause randomly. With a probability of at least 55%, flip the truth values of enough literals in the chosen clause to satisfy it. Repeat these steps iteratively, and the algorithm will, on average, satisfy at least 55% of the clauses. The polynomial-time complexity is maintained as each iteration involves a polynomial number of operations. This algorithm provides a balance between random exploration and exploitation, yielding a solution that meets the specified satisfaction threshold for a Max-SAT problem with clauses of varying lengths.
#
# **Example:**
#
# Consider a 3-SAT formula with three clauses: (A OR ¬B OR C), (¬A OR B OR ¬C), and (A OR B OR ¬C). Each clause has three literals, and we want to estimate the number of satisfying assignments using a randomized approximate counting algorithm.
#
# **Algorithm Execution:**
#
# Random Assignment: Start by randomly assigning truth values to the literals. For instance, one assignment could be A = true, B = false, C = true.
#
# Evaluate Satisfying Assignments: Check how many clauses are satisfied by the current assignment. In this case, the first and third clauses are satisfied, but the second is not.
#
# Repeat Random Assignments: Generate additional random assignments and evaluate the ratio of satisfying assignments. Suppose after multiple assignments, 60% of them satisfy the clauses.
#
# Estimation: Based on the observed ratio, estimate that approximately 60% of all possible assignments satisfy the entire 3-SAT formula.
#
# This algorithm provides a probabilistic estimate of the number of satisfying assignments, allowing us to gauge the solution space without exhaustively counting all possibilities, which could be computationally infeasible.

# %% [markdown]
# **Q4.** Subset Sum with a Twist:
#
# **Input:**
#
# - given A set of positive numbers S.
#
# - A target sum b.
#
# **Output:**
#
# Determine whether there exists a subset s' of S such that:
# The sum of the chosen elements in s' is equal to b.
#
# (The chosen elements form a subsequence in ascending order.)
#
# a.Is the SORTED-SUBSEQUENCE-SUBSETSUM NP-Complete? If so, prove it.
# If not, come up with a polynomial-time algorithm to find the subset S.
#
# b. SUPER-INCREASING-SUBSETSUM: Now consider a scenario where the list of numbers in A, in addition
# to being sorted, also satisfy the following property, i.e.
# For any 0 < k ≤ n, the element at position k.
# Is the SUPER-INCREASING-SUBSETSUM NP-Complete? If so, prove it. Else, propose a polynomial-time algorithm to find the subset S
#
#
# **Solution**
#
# Proof:
#
# Given an instance of the SUBSET-SU
# blem with a set of positive numbers S and a target sum
# b, we can create an instance of the SORTED-SUBSEQUENCE-SUBSETSUM problem with the same set S and target sum b.
# 1. Subset Sum to Sorted-Subsequence-SubsetSum Transformation:
# • For each element x in the set S, create a tuple (x, i) where i is the index of a in the original set S.
# • Sort the tuples lexicographically based on the first element, breaking ties by the second element.
# • Let S' be the sorted set of tuples.
# 2. Claim:
# There exists a subset S" of S' such that the sum of the chosen elements in S" is equal to b if and only if there exists a subset S" of S such that the sum of the chosen elements in S" is equal to b.
# 3. Proof of Claim:
# • If there exists a subset S" of S with sum b, then the corresponding tuples in S' (sorted version of S) will also have the same sum b because the sorting does not change the sum of the chosen elements.
# • Conversely, if there exists a subset S" of S' with sum b, we can project it back to the original set S by taking the first element of each tuple in S' , and the sum will remain b.
# 4. Conclusion:
# Since the transformation is polynomial timejand there is a one-to-one correspondence between solutions of SUBSET-SUM and SORTED-SUBSEQUENCE-SUBSETSUM, SORTED-SUBSEQUENCE-SUBSETSUM is NP-Complete.
# For the second part of your question, SUPER-INCREASING-SUBSETSUM:
# The problem you described does not appear to be NP-Complete. It seems that you can solve it in polynomial time using a dynamic programming approach.
# Polynomial-Time Algorithm for SUPER-INCREASING-SUBSETSUM:
# Given a sorted list A and a target sum b, you can use dynamic programming to determine whether there exists a super-increasing subset whose sum is equal to b.
# 1. Initialize a boolean array dp of size b + 1 with all values set to False.
# 2. Set dp|0] = True since the sum of an empty set is zero.
# 3. Iterate through each element x in A.
# • For each i from b to x, update dp|i] to be the logical OR of dp|2] and dp|i - x].
# 4. If dp|b] is True, then there exists a super-increasing subset whose sum is b.
#
# **Explanation:**
#
# The dynamic programming arra
# s used to keep track of the possible sums that can be
# achieved with the elements in A. For each element x in A, we update the array to represent the possible sums that can be achieved with or without using x. If dp|b] is True at the end, it means there exists a super-increasing subset whose sum is b.
# This algorithm runs in polynomial time, making SUPER-INCREASING-SUBSETSUM polynomial,. not NP-Complete.
#
# **Example** for NP-Completeness Proof (SORTED-SUBSEQUENCE-SUBSETSUM):
#
# Consider the SUBSET-SUM problem with the set S = {3, 1, 4, 2} and target sum b = 5.
#
# 1. Transformation:
#
# • Create tuples: (3, 1), (1, 2), (4,3), (2, 4).
#
# • Sort tuples: (1, 2), (2, 4), (3, 1), (4, 3).
#
# • The sorted set is S' = {(1,2), (2, 4), (3, 1), (4, 3)}.
#
# 2. Claim:
#
# There exists a subset S" of S' such that the sum of the chosen elements in S" is equal to b if and only if there exists a subset S" of S' such that the sum of the chosen elements in S" is equal to b.
#
# 3. Example:
#
# • Subset-Sum has a solution: S' = {1, 4} with sum b = 5.
#
# • Corresponding subset in S': S" = {(1, 2), (4, 3)} with sum b = 5.
#
# 4. Conclusion:
#
# The transformation preserves the existence of a subset with the desired sum. Since SUBSET-SUM is known to be NP-Complete, SORTED-SUBSEQUENCE-SUBSETSUM is also NP-Complete.
#
#
#
#
# **Example for Polynomial-Time Algorithm (SUPER-INCREASING-SUBSETSUM):**
#
# Consider the sorted list A ={1,2,4,8} and target sum b = 6.
#
# 1. Dynamic Programming:
#
# • Initialize dp array: [True, False, False, False, False, False, False]
#
# • Iterate through A:
#
# • For x = 1: Update dp to [True, True, False, False, False, False, False]
#
# • For x = 2: Update dp to [True, True, True, True, False, False, False].
#
# • For x = 4: Update dp to [True, True, True, True, True, True, True].
#
# 2. Result:
#
# The final dp array is [True, True, True, True, True, True, True], and dp[6] is True.
#
# 3. Conclusion:
#
# The algorithm determines that there exists a super-increasing subset of A whose sum is b = 6.
# In this case, the subset is {2, 4}.
#
# This dynamic programming algorithm runs in polynomial time and efficiently solves the SUPER-INCREASING-SUBSETSUM problem.

# %% [markdown]
# **Q5.** Given a social network represented as a graph where nodes represent individuals and edges represent influence relationships (e.g., A influences B), and a positive integer k, determine if there exists a set of k individuals such that every other individual in the network is either in this set or influenced by someone in this set.
#
# a. Show that SOCIAL-INFLUENCER is NP-Complete
#
# b. Would it be easier to simply conclude on the possibility (true/false) of finding such d friends rather than actually finding the list of those friends?
#
# **Solution:**
#
# a. Proving SOCIAL-INFLUENCER is NP-Complete:
#
# 1.SOCIAL-INFLUENCER is in NP:
#
# Given a set of individuals as a potential solution, you can easily verify whether every other individual in the network is either in this set or influenced by someone in this set. This verification can be done in polynomial time.
#
# 2.SOCIAL-INFLUENCER is NP-Hard:
#
# - To prove NP-Hardness, you can reduce a known NP-Complete problem (e.g., 3SAT or Independent Set) to SOCIAL-INFLUENCER. This involves showing that an instance of the known NP-Complete problem can be transformed into an instance of SOCIAL-INFLUENCER in polynomial time.
#
# - Suppose you want to reduce from 3SAT. Given a 3SAT instance with variables X and clauses C, construct a social network where each variable X and its negation ~X correspond to two individuals. Create influence edges based on the clauses C, ensuring that each clause is represented in the graph. The goal is to find a set of k individuals such that every other individual is either in the set or influenced by someone in the set.
#
# - The reduction process should show that a solution to the SOCIAL-INFLUENCER instance corresponds to a satisfying assignment for the 3SAT instance, and vice versa.
#
# - Since the reduction can be done in polynomial time, this establishes the NP-Hardness of SOCIAL-INFLUENCER.
#
# 3.Conclusion:
#
# By demonstrating that SOCIAL-INFLUENCER is in NP and NP-Hard, you establish that it is NP-Complete.
#
# **b. Conclusion on finding such individuals:**
#
# It is often easier to determine the possibility (true/false) of finding such a set of individuals (i.e., the decision problem) rather than actually finding the list of those individuals (i.e., the optimization problem). This is because the decision problem only requires a binary answer, while the optimization problem involves finding a specific solution.
#
# In the case of SOCIAL-INFLUENCER, proving the existence of a set of k individuals meeting the given criteria may be more manageable than providing the actual list of those individuals. The decision problem is likely to be more tractable than the optimization problem, which might involve searching through a potentially large solution space.
#
# In many cases, decision problems are used to establish the hardness of a problem (NP-Completeness), and practical algorithms may focus on approximations or heuristics rather than finding an exact solution.
#
#
#
# **Reduction from Independent Set to SOCIAL-INFLUENCER:**
#
# Independent Set (IS) Problem:
#
# Given an undirected graph G and a positive integer k, does there exist an independent set of size k in G?
#
# SOCIAL-INFLUENCER Problem:
#
# Given a social network represented as a graph where nodes represent individuals and edges represent influence relationships, and a positive integer k, does there exist a set of k individuals such that every other individual in the network is either in this set or influenced by someone in this set?
#
# Reduction:
#
# - For each vertex v in the Independent Set instance, create an individual in the SOCIAL-INFLUENCER instance.
# - For each edge (u, v) in the Independent Set instance, create an influence edge between the corresponding individuals in the SOCIAL-INFLUENCER instance.
#
# Explanation:
#
# - In the Independent Set instance, an independent set represents a set of vertices with no two adjacent vertices. In the SOCIAL-INFLUENCER instance, the set of individuals corresponds to an independent set in the graph, and the influence edges ensure that individuals in the set or influenced by someone in the set form an "independent" set in the social network.
#
# Proof:
#
# - If there exists an independent set of size k in the original graph (Independent Set instance), then the corresponding set of k individuals in the SOCIAL-INFLUENCER instance satisfies the conditions for SOCIAL-INFLUENCER.
#
# - If there exists a set of k individuals in the SOCIAL-INFLUENCER instance that satisfies the conditions, it forms an independent set in the original graph (Independent Set instance).
#
# Conclusion:
#
# This reduction shows that the SOCIAL-INFLUENCER problem is at least as hard as the Independent Set problem. Since Independent Set is known to be NP-Complete, this implies that SOCIAL-INFLUENCER is also NP-Complete.
